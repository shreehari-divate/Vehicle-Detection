# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install Ultralytics

# %%
from ultralytics.models import yolo

# %%
! yolo task=detect mode=train model=yolov8m.pt data=../content/drive/MyDrive/Datasets/vehicle/data.yaml epochs=100 imgsz=200
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 249MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=../content/drive/MyDrive/Datasets/vehicle/data.yaml epochs=100 imgsz=200 plots = True
# Out:
# WARNING ⚠️ imgsz=[200] must be multiple of max stride 32, updating to [224]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/Datasets/vehicle/valid/labels.cache... 125 images, 0 backgrounds, 0 corrupt: 100% 125/125 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:03<00:00,  2.21it/s]
#                    all        125        227      0.706      0.532      0.572      0.453
#              Ambulance        125         32      0.838      0.719      0.816       0.71
#                    Bus        125         23      0.832      0.645      0.736      0.655
#                    Car        125        119       0.64      0.395      0.427      0.301
#             Motorcycle        125         23      0.663      0.565      0.526      0.344
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf = 0.25 source=../content/drive/MyDrive/Datasets/vehicle/test/images
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/63 /content/../content/drive/MyDrive/Datasets/vehicle/test/images/00dea1edf14f09ab_jpg.rf.bdb7bcdfbf93548fdfcd7a546a855874.jpg: 224x224 1 Ambulance, 1 Car, 12.6ms
# image 2/63 /content/../content/drive/MyDrive/Datasets/vehicle/test/images/00e481ea1a520175_jpg.rf.3eeb0a2450de2efbe7f4f4b4e6f18742.jpg: 224x224 4 Buss, 12.6ms
# image 3/63 /content/../content/drive/MyDrive/Datasets/vehicle/test/images/08c8b73e0c2e296e_jpg.rf.170a6ea3991f6675597afe63f44f5dde.jpg: 224x224 2 Buss, 12.6ms
# image 4/63 /content/../content/drive/MyDrive/Datasets/vehicle/test/images/10c26c6598677a1f_jpg.rf.25fcace87a66f1ded540d34eb3da77e9.jpg: 224x224 1 Motorcycle, 12.7ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf = 0.25 source=../content/vehicle_vid3.mp4
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 111.9ms
# video 1/1 (2/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.5ms
# video 1/1 (3/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.6ms
# video 1/1 (4/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.7ms
# video 1/1 (5/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.4ms
# video 1/1 (6/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.8ms
# video 1/1 (7/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.7ms
# video 1/1 (8/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.4ms
# video 1/1 (9/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.3ms
# video 1/1 (10/813) /content/../content/vehicle_vid3.mp4: 128x224 1 Car, 14.3ms
# ...
